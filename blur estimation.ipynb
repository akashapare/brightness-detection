# %%
import skimage
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
def blur_est(img):
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    return cv2.Laplacian(gray, cv2.CV_64F).var()

# %%
in_Path ='D:/placements/blinkin/dataset/dataset/default'

# %% [markdown]
# ### trial on image with diffrent illumation conditions

# %%
i=0
plt.figure(figsize=(20,20))
for imagePath in os.listdir(in_Path):
        i+=1
        inputPath = os.path.join(in_Path, imagePath)
        img=cv2.imread(inputPath)
        img=cv2.resize(img,(224,224))
        blur_index=blur_est(img)
        plt.subplot(5,5,i)
        n=plt.imshow(img)
        if i==10:
            break
        plt.title(np.round(blur_index))
